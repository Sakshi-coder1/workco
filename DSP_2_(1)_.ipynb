# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakshi-coder1/workco/blob/main/DSP_2_(1)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a=np.array([2,5,6,36,78])
print(a)
# Out:
# [ 2  5  6 36 78]

# %%
b=np.array([[4,6], [7,2]])
print(b)
# Out:
# [[4 6]
#  [7 2]]

# %%
c=a+5
print(c)
# Out:
# [ 7 10 11 41 83]

# %%
d=a*3
print(d)
# Out:
# [  6  15  18 108 234]

# %%
print("Mean",np.mean(a))
# Out:
# Mean 25.4

# %%
print("sum",np.sum(a))
# Out:
# sum 127

# %%
print("Maxium number",np.max(a))
# Out:
# Maxium number 78

# %%
arr=np.array([10,20,30,40])
print(arr[3])
# Out:
# 40

# %%
print(arr[0:3])
# Out:
# [10 20 30]
