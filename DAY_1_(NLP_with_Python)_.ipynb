# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakshi-coder1/workco/blob/main/DAY_1_(NLP_with_Python)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
text='I LOVE this movie! It was amazing and exicting.'
print(text)
# Out:
# I LOVE this movie! It was amazing and exicting.

# %%
# Lowercase
text=text.lower()
print(text)
# Out:
# i love this movie! it was amazing and exicting.

# %%
# Remove punctuction marks
import string
text=text.translate(str.maketrans('','',string.punctuation))
print(text)
# Out:
# i love this movie it was amazing and exicting

# %%
# Tokenization
tokens=word_tokenize(text)
print(tokens)
# Out:
# ['i', 'love', 'this', 'movie', 'it', 'was', 'amazing', 'and', 'exicting']

# %%
# Stop words removal
stop_words=set(stopwords.words('english'))
print(stop_words)
# Out:
# {'did', 'needn', 'an', "they'd", 'himself', 'had', "we've", 'yourself', 'the', 'hasn', "they'll", 're', 'between', "it'd", "mustn't", 'she', 'wasn', 'where', 'ourselves', 'we', 'of', 'too', "should've", "wasn't", "wouldn't", 'why', "doesn't", "he'd", 'them', "we'll", 'below', 'during', 'my', 'their', 'while', 'ain', 'they', 'a', "couldn't", 'ma', 'mustn', 'he', 'as', 'off', 'if', 'doesn', "it'll", 'at', "shouldn't", 'your', 'aren', 'does', "she'll", 'it', 'just', "he'll", "weren't", 'down', 'most', 'doing', "they've", 'his', 've', "mightn't", "you've", 'over', 'against', 'how', "shan't", 'yourselves', "hadn't", 'ours', 'there', 'to', 'themselves', 'having', 'do', 'few', 'who', 'about', 'very', "i'll", 'our', "hasn't", "they're", "it's", 'once', 'should', "he's", 'shouldn', 'him', 'herself', 'or', 'don', "don't", 'by', 'nor', 'hers', 'which', "i'd", 'this', 'will', 'both', "aren't", 'again', 'up', 'd', 'its', 'mightn', 'y', 'be', "haven't", 'some', "won't", 'itself', "you'd", "isn't",
# ...

# %%
filtered_words=[]
for word in tokens:
  if word not in stop_words:
    filtered_words.append(word)
print(filtered_words)
# Out:
# ['love', 'movie', 'amazing', 'exicting']

# %%
# Lemmatization
nltk.download('wordnet')
lemmatizer=nltk.WordNetLemmatizer()
filtered_words=[
    lemmatizer.lemmatize(word)
    for word in filtered_words
]
print(filtered_words)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ['love', 'movie', 'amazing', 'exicting']
